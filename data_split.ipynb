# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data.csv")
data
# Out:
#                     timestamp       node_id   subsystem         sensor  \
# 0         2018/06/21 00:05:00  001e0610eef2  alphasense         opc_n2
# 1         2018/06/21 00:05:00  001e0610eef2   chemsense            at0
# 2         2018/06/21 00:05:00  001e0610eef2   chemsense            at1
# 3         2018/06/21 00:05:00  001e0610eef2   chemsense            at2
# 4         2018/06/21 00:05:00  001e0610eef2   chemsense            at3
# ...                       ...           ...         ...            ...
# 27162536  2018/09/23 23:55:00  001e0610ee33    metsense        pr103j2
# 27162537  2018/09/23 23:55:00  001e0610ee33    metsense  spv1840lr5h_b
# 27162538  2018/09/23 23:55:00  001e0610ee33    metsense         tmp112
# 27162539  2018/09/23 23:55:00  001e0610ee33    metsense       tsl250rd
# 27162540  2018/09/23 23:55:00  001e0610ee33    metsense         tsys01
#
#             parameter value_hrf_sum  value_hrf_count  value_hrf_average
# ...

# %%
rt = np.array_split(data, 10)

# %%
rt[0]
# Out:
#                    timestamp       node_id   subsystem    sensor  \
# 0        2018/06/21 00:05:00  001e0610eef2  alphasense    opc_n2
# 1        2018/06/21 00:05:00  001e0610eef2   chemsense       at0
# 2        2018/06/21 00:05:00  001e0610eef2   chemsense       at1
# 3        2018/06/21 00:05:00  001e0610eef2   chemsense       at2
# 4        2018/06/21 00:05:00  001e0610eef2   chemsense       at3
# ...                      ...           ...         ...       ...
# 2716250  2018/06/28 23:45:00  001e061146ba    metsense  metsense
# 2716251  2018/06/28 23:45:00  001e061146ba    metsense  mma8452q
# 2716252  2018/06/28 23:45:00  001e061146ba    metsense  mma8452q
# 2716253  2018/06/28 23:45:00  001e061146ba    metsense  mma8452q
# 2716254  2018/06/28 23:45:00  001e061146ba    metsense   pr103j2
#
#               parameter value_hrf_sum  value_hrf_count  value_hrf_average
# 0                    fw           NaN                1              0.000
# ...

# %%
for i in range(0, 10):
    name = "./data_split/data"+str(i)+".csv"
    rt[i].to_csv(name)
